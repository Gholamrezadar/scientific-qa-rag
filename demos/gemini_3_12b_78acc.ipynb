# %%
# %%capture
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
# !nohup ollama serve &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# %%capture
# !ollama pull gemma3:1b
# !ollama pull gemma3:12b-it-qat
# !ollama pull nomic-embed-text

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/Gholamrezadar/scientific-qa-rag.git
# Out:
# Cloning into 'scientific-qa-rag'...
# remote: Enumerating objects: 279, done.
# remote: Counting objects: 100% (279/279), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 279 (delta 143), reused 202 (delta 66), pack-reused 0 (from 0)
# Receiving objects: 100% (279/279), 771.34 KiB | 2.42 MiB/s, done.
# Resolving deltas: 100% (143/143), done.

# %%
# %cd /content/scientific-qa-rag
# Out:
# /content/scientific-qa-rag

# %%
# %ls
# Out:
# chroma_test.py          evaluate_ollama.ipynb  qa_rag.py
# data/                   FUTURE.md              README.md
# demos/                  gemma3_1b_ypred.txt    requirements.txt
# diagrams/               phi_results            src/
# evaluate_chatgpt.ipynb  playground.ipynb       testing_keywords.ipynb
# evaluate_gemma.py       PROMPTS.md             TODO.md

# %%
# %%capture
# !pip install langchain_community langchain_chroma langchain_ollama chromadb

# %%
# %pwd
# Out:
# '/content/scientific-qa-rag'

# %%
# !rm -rf ./rag_db

# %%
# !python qa_rag.py --kw-model "gemma3:12b-it-qat" --answer-model "gemma3:12b-it-qat" --dataset ./data/train_data.csv --num-samples 50 --chunk-size 10000
# Out:
# Initializing Langchain...
# Initializing Chroma DB...
# 2025-05-07 22:02:34,600 - Loading dataset...
# 2025-05-07 22:02:34,604 - Loaded 50 questions
#
# 2025-05-07 22:02:34,604 - Creating keyword prompts from questions...
# 2025-05-07 22:02:34,607 - Successfully created 50 keyword prompts
#
# 2025-05-07 22:02:34,608 - Generating keywords using "gemma3:12b-it-qat"...
# Keywords for question 0: Star
# Keywords for question 1: Planck's_law
# Keywords for question 2: Carnot engine
# Keywords for question 3: Light-ion fusion
# Keywords for question 4: Coffee-ring-effect
# Keywords for question 5: Water hammer
# Keywords for question 6: Memristor
# Keywords for question 7: Fermi-level
# Keywords for question 8: Photometry
# Keywords for question 9: Classicalmechanics
# Keywords for question 10: Canonical quantization
# Keywords for question 11: Cosmology
# Keywords for question 12: Frame-dragging
# Keywords for question 13: SETI
# Keywords for question 14: Photosynthesis
# ...

# %%
# !python qa_rag.py --dataset ./data/train_data.csv --num-samples 50
# Out:
# Initializing Langchain...
# Initializing Chroma DB...
# 2025-05-07 20:19:45,419 - Loading dataset...
# 2025-05-07 20:19:45,423 - Loaded 50 questions
#
# 2025-05-07 20:19:45,424 - Creating keyword prompts from questions...
# 2025-05-07 20:19:45,426 - Successfully created 50 keyword prompts
#
# 2025-05-07 20:19:45,426 - Generating keywords using "gemma3:1b"...
# Keywords for question 0: Main sequence, stars, stellar evolution
# Keywords for question 1: UV radiation, atmospheric absorption, ozone depletion, greenhouse effect
# Keywords for question 2: Carnot cycle, thermodynamic cycle, efficiency
# Keywords for question 3: Fusion, accelerator, light
# Keywords for question 4: coffee, ring, physics
# Keywords for question 5: Hydraulic dynamics, water flow, resonance
# Keywords for question 6: Memristor, resistance, current, circuit
# Keywords for question 7: Fermi level, density of states, entropy
# Keywords for question 8: illuminance, luminance, measurement
# ...
